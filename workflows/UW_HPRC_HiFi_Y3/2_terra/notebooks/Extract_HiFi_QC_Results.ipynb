# %% [markdown]
# # Extract HiFi QC Data<a class="tocSkip">
#
# **This notebook reads in data from NTSM and ReadStats WDLS (stored in data tables). This is part of the HiFi QC process.**
#
# **Below are the steps taken in this notebook:**
# 1. Import Statements & Global Variable Definitions
# 2. Define Functions
# 3. Read In Sample Names
# 4. Create Dataframe Of Files
# 5. Write data frame to data tables

# %% [markdown]
# # Import Statements & Global Variable Definitions

# %% [markdown]
# ## Installs

# %%
# %%capture
# %pip install gcsfs
## capture CANNOT have comments above it
## For reading CSVs stored in Google Cloud (without downloading them first)
## May need to restart kernel after install

# %%
# %%capture
# %pip install --upgrade --no-cache-dir --force-reinstall terra-pandas
# %pip install --upgrade --no-cache-dir  --force-reinstall git+https://github.com/DataBiosphere/terra-notebook-utils
## For reading/writing data tables into pandas data frames
## May need to restart kernel after install

# %% [markdown]
# ## Import Statements

# %%
from firecloud import fiss
import pandas as pd 
import numpy as np
import terra_pandas as tp
import os                 
import subprocess       
import re                 
import io
import gcsfs

from typing import Any, Callable, List, Optional
from terra_notebook_utils import table, WORKSPACE_NAME, WORKSPACE_GOOGLE_PROJECT

# %% [markdown]
# ## Global Variable Declarations

# %%
# Get the Google billing project name and workspace name for current workspace
PROJECT = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE =os.path.basename(os.path.dirname(os.getcwd()))
bucket = os.environ['WORKSPACE_BUCKET'] + "/"


# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: HPRC_WRANGLING_UW_HPRC_HiFi_Y3
# Workspace storage bucket: gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/

# %% [markdown]
# # Extract NTSM Data

# %% [markdown]
# ## Read in NTSM Data Table

# %%
ntsm_df = tp.table_to_dataframe("ntsm", workspace=WORKSPACE, workspace_namespace=PROJECT)

ntsm_df.head()
# Out:
#                                               ntsv_count_2  \
# ntsm_id
# HG00099  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
#
#                                               ntsv_count_1  \
# ntsm_id
# HG00099  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
#
#                                                       hifi  \
# ntsm_id
# HG00099  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00280  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00558  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00639  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG01074  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                 1000g_cram  \
# ntsm_id
# HG00099  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG00280  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG00558  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG00639  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG01074  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
#
#                                              ntsm_eval_out
# ntsm_id
# HG00099  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...

# %% [markdown]
# ## Read NTSM Output & Write To DataFrame

# %%
ntsm_df['ntsm_score'] = np.nan
ntsm_df['result']     = np.nan

for index, row in ntsm_df.iterrows():

        sample_ntsm_fp = row['ntsm_eval_out']
        sample_ntsm_fn = os.path.basename(sample_ntsm_fp)

        ! gsutil cp {sample_ntsm_fp} .
        
        sample_ntsm_df = pd.read_csv(sample_ntsm_fn, header=None, sep='\t')

        ntsm_df['ntsm_score'][index] = sample_ntsm_df[2]
        ntsm_df['result'][index]     = sample_ntsm_df[3].astype('str')[0]
# Out:
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/d572bc00-3943-494a-bed8-cfddb30a1848/ntsm_workflow/2a7ef75f-352c-46f8-a78c-c2246a406196/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/d572bc00-3943-494a-bed8-cfddb30a1848/ntsm_workflow/2985c3a1-3e42-40e2-9efa-4458a74503ad/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/2ea3f12a-1c72-4dcb-b24d-393ae92866ff/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/c84df0bc-edde-44eb-b873-4ce78bf382c5/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/77785c85-4612-40dd-b2a3-086a87269d51/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/cf27d0d7-90ac-4518-84c5-5a1c8ffd2fe5/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/865b7319-c51c-4fb3-bc7f-b58c5af28bbd/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/f3cb4804-c0f5-4c8f-9ef9-6d772a1cc6ae/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/dbf84f14-744d-4d96-9fe9-42e731d6840e/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/272fccfb-7ecf-4de3-851d-0e3335b562fb/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/e0bc5b0f-b10d-4c23-b8e4-97c7e6cb8b7f/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/0dc6b656-fee9-4f12-b140-28207268c61e/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/93b94d96-6bee-4c9a-839f-585033779ca2/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/2c1996e8-423d-4e02-833e-ff7248ac0407/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  434.0 B/  434.0 B]
# Operation completed over 1 objects/434.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/4d8d7560-dd5e-4d9d-97f6-fc95390620d1/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/be4202ad-ac0e-4285-b320-5449a858eaa7/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/1a9e765c-19dc-412e-9601-3f10e086bf75/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/491c174f-2769-4b4b-a9f6-07e55b06ca4a/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/7635b846-9163-40b6-833e-1d9200085d4f/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/076a3ebe-9909-4d04-a408-8678345d8e09/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/02b04fe2-079e-425c-8019-2ee6784bb063/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/82256ad7-7a05-436d-8f19-654d45fd26e2/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/02f3f8c2-0338-4e64-a374-32f0f3f9a88f/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  424.0 B/  424.0 B]
# Operation completed over 1 objects/424.0 B.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/83ef6c7c-17f7-4cb1-8709-2809ad2975ea/ntsm_workflow/cd22c870-eff4-4584-a616-910a73fb4cd3/call-ntsm_eval/sample_1000genome_Illumina_vs_hifi.txt...
# / [1 files][  434.0 B/  434.0 B]
# Operation completed over 1 objects/434.0 B.

# %%
ntsm_df
# Out:
#                                               ntsv_count_2  \
# ntsm_id
# HG00099  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01081  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02040  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02165  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02451  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02735  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02922  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03017  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03041  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03130  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03139  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03209  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03239  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03704  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18522  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18747  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18983  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA19043  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA20752  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA20905  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
#
#                                               ntsv_count_1  \
# ntsm_id
# HG00099  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01081  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02040  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02165  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02451  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02735  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02922  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03017  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03041  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03130  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03139  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03209  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03239  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03704  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18522  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18747  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18983  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA19043  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA20752  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA20905  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
#
#                                                       hifi  \
# ntsm_id
# HG00099  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00280  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00558  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00639  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG01074  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG01081  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02040  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02165  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02451  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02735  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02922  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03017  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03041  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03130  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03139  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03209  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03239  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03704  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA18522  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA18747  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA18983  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA19043  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA20752  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA20905  [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                 1000g_cram  \
# ntsm_id
# HG00099  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG00280  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG00558  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG00639  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG01074  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG01081  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG02040  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG02165  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG02451  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG02735  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG02922  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03017  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03041  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03130  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03139  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03209  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03239  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# HG03704  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# NA18522  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# NA18747  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# NA18983  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# NA19043  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# NA20752  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
# NA20905  gs://fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e/C...
#
#                                              ntsm_eval_out  ntsm_score  \
# ntsm_id
# HG00099  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.496386
# HG00280  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.525210
# HG00558  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.488614
# HG00639  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.486938
# HG01074  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.508654
# HG01081  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.511131
# HG02040  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.516192
# HG02165  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.521418
# HG02451  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.506510
# HG02735  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.477988
# HG02922  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.524768
# HG03017  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.522185
# HG03041  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.503519
# HG03130  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.557994
# HG03139  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.449914
# HG03209  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.519385
# HG03239  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.510999
# HG03704  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.521003
# NA18522  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.523902
# NA18747  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.505619
# NA18983  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.545966
# NA19043  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.516232
# NA20752  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.520721
# NA20905  gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...    0.533663
#
#           result
# ntsm_id
# HG00099  Similar
# HG00280  Similar
# HG00558  Similar
# HG00639  Similar
# HG01074  Similar
# HG01081  Similar
# HG02040  Similar
# HG02165  Similar
# HG02451  Similar
# HG02735  Similar
# HG02922  Similar
# HG03017  Similar
# HG03041  Similar
# HG03130  Similar
# HG03139  Similar
# HG03209  Similar
# HG03239  Similar
# HG03704  Similar
# NA18522  Similar
# NA18747  Similar
# NA18983  Similar
# NA19043  Similar
# NA20752  Similar
# NA20905  Similar

# %%
## How many rows don't match??? (Should be 0)
sum(ntsm_df['result'] != 'Similar')
# Out:
# 0

# %% [markdown]
# # Extract ReadStats Data

# %% [markdown]
# ## Read in ReadStats Data Table

# %%
readstats_df = tp.table_to_dataframe("readstats", workspace=WORKSPACE, workspace_namespace=PROJECT)

readstats_df.head()
# Out:
#                                                ReadStatsTarball  \
# readstats_id
# HG00099       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
#
#                                                            hifi  \
# readstats_id
# HG00099       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00280       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00558       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00639       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG01074       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                 ReadStatsReport
# readstats_id
# HG00099       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...

# %% [markdown]
# ## Read ReadStats Output & Write To DataFrame

# %%
readstats_df['output']   = np.nan

for index, row in readstats_df.iterrows():

        sample_readstats_fp = row['ReadStatsReport']
        sample_readstats_fn = os.path.basename(sample_readstats_fp)

        ! gsutil cp {sample_readstats_fp} .
        
        sample_readstats_df = pd.read_csv(sample_readstats_fn, header=None, sep='\t')

        ## Just look at sample-level metrics
        sample_readstats_df = sample_readstats_df[sample_readstats_df[0]=='sample.fastq']

        ## Get rid of extra row
        sample_readstats_df = sample_readstats_df.iloc[1: , :]


        sample_coverage = sample_readstats_df[sample_readstats_df[1] == 'total_Gbp'][2]
        readstats_df['output'][index] = float(sample_coverage.values[0])

        
readstats_df['coverage'] = readstats_df['output']/3.1
# Out:
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/c9a54e77-e953-4fa7-978f-dde608fd1637/runReadStats/680cc0a8-4d66-40c4-a3db-00a5122d29ff/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/cf90cb25-5cac-43df-9a0a-d14a4fce6cc7/runReadStats/cd30c762-5013-4d96-af90-97985e2abe8e/call-consolidateReadStats/attempt-2/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/c9a54e77-e953-4fa7-978f-dde608fd1637/runReadStats/03cf30f3-cca7-44eb-9b39-ed38144682a1/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/1be66890-fd13-4f32-bfa3-08b55ac7cde7/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/91a400a6-62dc-4fd4-865a-42262457da51/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/cfb29a7e-2693-47b1-a1cc-31f92dc04536/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/5709f886-6204-4b37-8a5f-0cc75a226073/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/43742efe-6ee7-4c3a-8180-84b6004e2be6/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/d6e7ff70-20e9-415e-ab58-249fec4edf3e/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/46bbdcfb-e1dc-4dfa-bb03-763146571f63/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/fdfe5bda-901e-471f-9eff-536f52068c44/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  5.7 KiB/  5.7 KiB]
# Operation completed over 1 objects/5.7 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/4fad6ebc-7baf-49dc-9538-ace9daecc804/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/5a42249c-5d93-4f6e-9674-4041d8144e3e/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/0e68e5fe-0ba2-49fd-99b0-a95051b30b5b/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/8d5dc757-9b1a-4950-8eee-c608df5f8497/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/d1eda1e0-3bd2-483c-8980-be54b0555604/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/6af22698-8c41-44c3-9ee0-d6d59f295082/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/52cf6e35-47e3-4c65-a26b-0fbd64ef5b53/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  4.9 KiB/  4.9 KiB]
# Operation completed over 1 objects/4.9 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/d6152c1e-0723-42ab-996b-46bee74c978f/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/6a067b23-3c78-4bb3-b4c2-b2f9558926b9/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/54727d0f-d529-4e98-a38f-0ed15b5fc593/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  4.9 KiB/  4.9 KiB]
# Operation completed over 1 objects/4.9 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/86f7df4d-1d82-49c1-b515-43c93b4604f7/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/a552eea4-1878-41ed-b27f-3458c812361d/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.
# Copying gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/submissions/b0a872c7-c9e1-41c8-9fb8-765c44f86128/runReadStats/1196f8ea-24f8-442e-82b3-7b272892f8be/call-consolidateReadStats/glob-44edd1a7587a8a70d756f66d9e5e0ada/sample_all.report.tsv...
# / [1 files][  2.6 KiB/  2.6 KiB]
# Operation completed over 1 objects/2.6 KiB.

# %%
readstats_df
# Out:
#                                                ReadStatsTarball  \
# readstats_id
# HG00099       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00280       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00558       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG00639       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01074       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG01081       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02040       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02165       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02451       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02735       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG02922       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03017       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03041       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03130       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03139       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03209       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03239       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# HG03704       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18522       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18747       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA18983       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA19043       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA20752       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
# NA20905       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...
#
#                                                            hifi  \
# readstats_id
# HG00099       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00280       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00558       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG00639       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG01074       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG01081       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02040       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02165       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02451       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02735       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG02922       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03017       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03041       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03130       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03139       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03209       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03239       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# HG03704       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA18522       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA18747       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA18983       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA19043       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA20752       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
# NA20905       [gs://fc-4310e737-a388-4a10-8c9e-babe06aaf0cf/...
#
#                                                 ReadStatsReport  output  \
# readstats_id
# HG00099       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  143.97
# HG00280       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  128.42
# HG00558       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  105.37
# HG00639       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  106.17
# HG01074       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  125.21
# HG01081       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  108.12
# HG02040       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  129.90
# HG02165       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  134.71
# HG02451       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  131.33
# HG02735       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  112.78
# HG02922       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  155.28
# HG03017       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  102.37
# HG03041       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  112.43
# HG03130       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  117.43
# HG03139       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  128.15
# HG03209       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  116.29
# HG03239       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  108.06
# HG03704       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  105.90
# NA18522       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  130.59
# NA18747       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  119.23
# NA18983       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  128.22
# NA19043       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  128.96
# NA20752       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  137.29
# NA20905       gs://fc-c2424fa0-8b70-4a0a-bd92-598d9fa71260/s...  128.90
#
#                coverage
# readstats_id
# HG00099       46.441935
# HG00280       41.425806
# HG00558       33.990323
# HG00639       34.248387
# HG01074       40.390323
# HG01081       34.877419
# HG02040       41.903226
# HG02165       43.454839
# HG02451       42.364516
# HG02735       36.380645
# HG02922       50.090323
# HG03017       33.022581
# HG03041       36.267742
# HG03130       37.880645
# HG03139       41.338710
# HG03209       37.512903
# HG03239       34.858065
# HG03704       34.161290
# NA18522       42.125806
# NA18747       38.461290
# NA18983       41.361290
# NA19043       41.600000
# NA20752       44.287097
# NA20905       41.580645

# %% [markdown]
# # Upload To Tables

# %%
## Create tables for running NTSM and ReadStats
dataframe_to_table("ntsm",      ntsm_df, WORKSPACE, PROJECT)
dataframe_to_table("readstats", sample_df, WORKSPACE, PROJECT)
